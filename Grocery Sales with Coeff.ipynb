# %% [markdown]
# # Create Project

# %%
#import libraries 
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

## Preprocessing tools
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer


## Models & evaluation metrics
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import joblib

# ## setting random state for reproducibility
SEED = 321
np.random.seed(SEED)

## Matplotlib style
fav_style = ('ggplot','tableau-colorblind10')
fav_context  ={'context':'notebook', 'font_scale':1.1}
plt.style.use(fav_style)
sns.set_context(**fav_context)
plt.rcParams['savefig.transparent'] = False
plt.rcParams['savefig.bbox'] = 'tight'

# %% [markdown]
# ## Functions

# %%
def evaluate_regression(model, X_train,y_train, X_test, y_test,for_slides=True): 
    
    ## Training Data
    y_pred_train = model.predict(X_train)
    r2_train = metrics.r2_score(y_train, y_pred_train)
    rmse_train = metrics.mean_squared_error(y_train, y_pred_train, 
                                            squared=False)
    mae_train = metrics.mean_absolute_error(y_train, y_pred_train)
    

    ## Test Data
    y_pred_test = model.predict(X_test)
    r2_test = metrics.r2_score(y_test, y_pred_test)
    rmse_test = metrics.mean_squared_error(y_test, y_pred_test, 
                                            squared=False)
    mae_test = metrics.mean_absolute_error(y_test, y_pred_test)
    
    if for_slides:
        df_version =[['Split','R^2','MAE','RMSE']]
        df_version.append(['Train',r2_train, mae_train, rmse_train])
        df_version.append(['Test',r2_test, mae_test, rmse_test])
        df_results = pd.DataFrame(df_version[1:], columns=df_version[0])
        df_results = df_results.round(2)
        display(df_results.style.hide(axis='index').format(precision=2, thousands=','))
        
    else: 
        print(f"Training Data:\tR^2 = {r2_train:,.2f}\tRMSE = {rmse_train:,.2f}\tMAE = {mae_train:,.2f}")
        print(f"Test Data:\tR^2 = {r2_test:,.2f}\tRMSE = {rmse_test:,.2f}\tMAE = {mae_test:,.2f}")

# %%
# get coefficients function
def get_coefficients(lin_reg):
    coeffs = pd.Series(lin_reg.coef_, index= lin_reg.feature_names_in_)
    coeffs.loc['intercept'] = lin_reg.intercept_
    return coeffs

# %%
# plot coefficients functions
def plot_coeffs(coeffs, top_n=None,  figsize=(4,5), intercept=False, 
                annotate=False, ha='left',va='center', size=12, xytext=(4,0),
                  textcoords='offset points'):
    """Plots the top_n coefficients from a Series, with optional annotations."""
    if (intercept==False) & ('intercept' in coeffs.index):
        coeffs = coeffs.drop('intercept')
    if top_n==None:
        ## sort all features and set title
        plot_vals = coeffs#.sort_values()
        title = "All Coefficients - Ranked by Magnitude"
    else:
        ## rank the coeffs and select the top_n
        coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
        top_n_features = coeff_rank.head(top_n)
        plot_vals = coeffs.loc[top_n_features.index].sort_values()
        ## sort features and keep top_n and set title
        title = f"Top {top_n} Largest Coefficients"
    ## plotting top N importances
    ax = plot_vals.plot(kind='barh', figsize=figsize)
    fig= ax.get_figure()
    ax.set(xlabel='Coefficient', 
           ylabel='Feature Names', 
           title=title)
    ax.axvline(0, color='k')
#sns.plt.show()
    if annotate==True:
        annotate_hbars(ax, ha=ha,va=va,size=size,xytext=xytext,
                       textcoords=textcoords)
    ## return ax in case want to continue to update/modify figure
    return ax

# %%
def annotate_hbars(ax, ha='left',va='center',size=12,  xytext=(4,0),
                  textcoords='offset points'):
    for bar in ax.patches:
    
        ## calculate center of bar
        bar_ax = bar.get_y() + bar.get_height()/2
        ## get the value to annotate
        val = bar.get_width()
        if val < 0:
            val_pos = 0
        else:
            val_pos = val
        # ha and va stand for the horizontal and vertical alignment
        ax.annotate(f"{val:.3f}", (val_pos,bar_ax), ha=ha,va=va,size=size,
                        xytext=xytext, textcoords=textcoords)

# %% [markdown]
# ##  Load the Data

# %%
#create pandas dataframe
filename='Data/sales_predictions - sales_predictions (1).csv'
df = pd.read_csv(filename)

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
## Display the number of rows and columns for the dataframe
df.shape
print(f'There are {df.shape[0]} rows, and {df.shape[1]} columns.')
print(f'The rows represent {df.shape[0]} observations, and the columns represent \
{df.shape[1]-1} features and 1 target variable.')
# Out:
# There are 8523 rows, and 12 columns.
# The rows represent 8523 observations, and the columns represent 11 features and 1 target variable.

# %%
# Fix the fat content row done in all projects
# fix the inconsistencies  in the "item_Fat_Content"
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('LF', 'Low Fat')
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('low fat', 'Low Fat')
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('reg', 'Regular')
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# ## Explore the data

# %%
#create EDA of the target
target = 'Item_Outlet_Sales'

grid_spec = {'height_ratios':[0.8,0.2]}
fig, axes = plt.subplots(nrows=2, figsize=(6,5), gridspec_kw=grid_spec)

sns.histplot(data=df, x=target,ax=axes[0])
sns.boxplot(data=df, x=target, ax=axes[1]);

# %% [markdown]
# ## Preprocessing

# %%
# Run the following command on your local computer to check the version of sklearn
import sklearn
# !python --version
print(f"sklearn version: {sklearn.__version__}")
# Out:
# Python 3.9.15
# sklearn version: 1.1.3

# %%
## Make x and y variables
target = "Item_Outlet_Sales"
drop_feats = []

y = df[target].copy()
X = df.drop(columns=[target, *drop_feats]).copy()

## train-test-split with random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=SEED)
X_train.head(3)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8269           FDI60        7.220          Regular         0.064142
# 7604           DRD25        6.135          Low Fat         0.079294
# 2762           NCP18       12.150          Low Fat         0.028593
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8269  Baking Goods   61.2510            OUT010                       1998
# 7604   Soft Drinks  111.2860            OUT018                       2009
# 2762     Household  151.0708            OUT035                       2004
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 8269         NaN               Tier 3      Grocery Store
# 7604      Medium               Tier 3  Supermarket Type2
# 2762       Small               Tier 2  Supermarket Type1

# %%
## Make numeric preprocessing pipeline
num_sel = make_column_selector(dtype_include='number')
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))
num_pipe

## Make categorical preprocessing pipeline
cat_sel = make_column_selector(dtype_include='object')
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))

# %%
## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),)
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000002720DB8DA90>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000027211711AC0>)])

# %%
## make the preprocessing column transformer 
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),
                                      verbose_feature_names_out=False)
preprocessor.fit(X_train)
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_test.index)
display(X_train_df)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
#
# 4707                            0.0
# ...                             ...
# 3482                            1.0
# 8360                            0.0
# 5929                            0.0
# 4220                            0.0
# 6682                            0.0
#
# [6392 rows x 1597 columns]

# %% [markdown]
# # Models

# %% [markdown]
# ## Baseline linear regression

# %%
# first lin reg
lin_reg= LinearRegression()
lin_reg.fit(X_train_df,y_train)
evaluate_regression(lin_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e49dd">
#   <thead>
#     <tr>
#       <th id="T_e49dd_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_e49dd_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_e49dd_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_e49dd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e49dd_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_e49dd_row0_col1" class="data row0 col1" >0.67</td>
#       <td id="T_e49dd_row0_col2" class="data row0 col2" >725.38</td>
#       <td id="T_e49dd_row0_col3" class="data row0 col3" >973.12</td>
#     </tr>
#     <tr>
#       <td id="T_e49dd_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_e49dd_row1_col1" class="data row1 col1" >-1,958,224,537,042,239.25</td>
#       <td id="T_e49dd_row1_col2" class="data row1 col2" >4,365,931,899.79</td>
#       <td id="T_e49dd_row1_col3" class="data row1 col3" >77,721,793,710.35</td>
#     </tr>
#   </tbody>
# </table>

# %%
#look at goefficients
coeffs = get_coefficients(lin_reg)
coeffs
# Out:
# Item_Weight                     -2.414338e+00
# Item_Visibility                 -7.949584e+02
# Item_MRP                        -1.107978e+01
# Outlet_Establishment_Year       -1.760337e+09
# Item_Identifier_DRA12            2.188858e+11
#                                      ...
# Outlet_Type_Grocery Store        8.393006e+12
# Outlet_Type_Supermarket Type1   -5.025634e+12
# Outlet_Type_Supermarket Type2   -8.368294e+11
# Outlet_Type_Supermarket Type3    1.018361e+12
# intercept                        1.530293e+13
# Length: 1598, dtype: float64

# %%
## formatting numbers to not use , thousands sep, and 4 digits floats
pd.set_option('display.float_format',lambda x: f"{x:,.4f}")
pd.set_option('display.max_rows', None)

# %%
coeffs.sort_values()
# Out:
# Outlet_Location_Type_Tier 3       -23,257,681,116,380.1641
# Outlet_Location_Type_Tier 1       -21,419,618,372,825.2656
# Item_Identifier_FDH09              -6,319,555,156,111.4072
# Item_Identifier_FDJ45              -6,319,555,156,065.3770
# Item_Identifier_FDK45              -6,319,555,154,136.5098
# Item_Identifier_FDF33              -6,319,555,153,621.1895
# Item_Identifier_FDH21              -6,319,555,152,827.8652
# Item_Identifier_FDI57              -6,319,555,150,650.1846
# Item_Identifier_FDG33              -5,795,365,403,286.7646
# Item_Identifier_FDG21              -5,795,365,402,691.7119
# Item_Identifier_FDJ57              -5,795,365,402,195.1152
# Item_Identifier_FDI09              -5,795,365,400,718.4707
# Outlet_Location_Type_Tier 2        -5,655,656,995,121.6621
# Outlet_Type_Supermarket Type1      -5,025,634,104,289.8027
# Outlet_Identifier_OUT027           -4,017,926,809,254.3369
# Outlet_Identifier_OUT035           -3,858,867,968,825.3931
# Item_Identifier_NCL07              -3,033,339,048,168.8979
# Item_Identifier_NCK31              -3,033,339,047,965.5942
# Item_Identifier_NCI31              -3,033,339,047,825.4458
# Item_Identifier_NCO02              -3,033,339,047,504.4331
# Item_Identifier_NCP55              -3,033,339,047,334.1992
# Item_Identifier_NCP50              -3,033,339,047,248.4219
# Item_Identifier_FDN13              -2,749,032,792,114.8921
# Item_Identifier_FDM13              -2,749,032,791,878.3677
# Item_Identifier_FDP37              -2,749,032,790,794.2354
# Item_Identifier_FDO13              -2,749,032,790,785.1006
# Item_Identifier_FDN01              -2,749,032,790,031.8149
# Item_Identifier_FDO37              -2,749,032,788,608.7983
# Item_Identifier_FDQ37              -2,749,032,787,622.9463
# Outlet_Identifier_OUT045           -2,510,861,923,984.6328
# Outlet_Identifier_OUT017           -2,502,060,238,783.9062
# Item_Type_Baking Goods             -2,433,614,771,887.4375
# Item_Identifier_FDO51              -2,280,716,560,746.7886
# Item_Identifier_FDQ51              -2,280,716,560,632.1436
# Item_Identifier_FDU15              -2,280,716,560,257.1562
# Item_Identifier_FDX03              -2,280,716,560,058.9185
# Item_Identifier_FDU27              -2,280,716,559,793.1255
# Item_Identifier_FDO15              -2,280,716,559,512.2710
# Item_Identifier_FDQ15              -2,280,716,559,321.7139
# Item_Identifier_FDZ39              -2,280,716,559,256.1216
# Item_Identifier_FDH31              -2,280,716,559,240.8643
# Item_Identifier_FDZ51              -2,280,716,559,056.2305
# Item_Identifier_FDV27              -2,280,716,559,043.4175
# Item_Identifier_FDO27              -2,280,716,558,909.5161
# Item_Identifier_FDT51              -2,280,716,558,796.8252
# Item_Identifier_FDM51              -2,280,716,558,779.5176
# Item_Identifier_FDS15              -2,280,716,558,729.6504
# Item_Identifier_FDQ27              -2,280,716,558,352.7715
# Item_Identifier_FDY03              -2,280,716,558,203.6035
# Item_Identifier_FDJ27              -2,280,716,558,185.1792
# Item_Identifier_FDW03              -2,280,716,558,127.8306
# Item_Identifier_FDW39              -2,280,716,557,930.3174
# Item_Identifier_FDU03              -2,280,716,557,913.0454
# Item_Identifier_FDP03              -2,280,716,557,881.9883
# Item_Identifier_FDP51              -2,280,716,557,775.7729
# Item_Identifier_FDT39              -2,280,716,557,751.8057
# Item_Identifier_FDR15              -2,280,716,557,735.8535
# Item_Identifier_FDR27              -2,280,716,557,697.3926
# Item_Identifier_FDW15              -2,280,716,557,672.9141
# Item_Identifier_FDW27              -2,280,716,557,514.6836
# Item_Identifier_FDM27              -2,280,716,557,400.9941
# Item_Identifier_FDL03              -2,280,716,557,369.6650
# Item_Identifier_FDR51              -2,280,716,557,307.3262
# Item_Identifier_FDN39              -2,280,716,557,184.0342
# Item_Identifier_FDM15              -2,280,716,557,109.6597
# Item_Identifier_FDS27              -2,280,716,557,063.5801
# Item_Identifier_FDT15              -2,280,716,556,987.0630
# Item_Identifier_FDQ03              -2,280,716,556,623.7227
# Item_Identifier_FDR03              -2,280,716,556,386.7163
# Item_Identifier_FDI07              -2,280,716,556,266.3364
# Item_Identifier_FDX51              -2,280,716,556,240.8901
# Item_Identifier_FDO39              -2,280,716,555,748.6943
# Item_Identifier_FDY39              -2,280,716,555,710.8433
# Item_Identifier_FDN03              -2,280,716,555,513.9927
# Item_Identifier_FDW51              -2,280,716,555,481.6440
# Item_Identifier_FDO03              -2,280,716,555,239.6865
# Item_Identifier_FDU51              -2,280,716,555,227.8291
# Item_Identifier_FDT27              -2,280,716,555,213.0864
# Item_Identifier_FDX39              -2,280,716,555,121.6890
# Item_Identifier_FDJ55              -2,280,716,554,521.0649
# Item_Identifier_FDN51              -2,280,716,553,931.6401
# Item_Type_Health and Hygiene       -2,255,732,807,492.2031
# Item_Identifier_FDN25              -2,224,843,043,950.0015
# Item_Identifier_FDL25              -2,224,843,043,828.0127
# Item_Identifier_FDO49              -2,224,843,043,780.5635
# Item_Identifier_FDN49              -2,224,843,043,749.6826
# Item_Identifier_FDP49              -2,224,843,043,697.0688
# Item_Identifier_FDM01              -2,224,843,042,247.0684
# Item_Identifier_FDO01              -2,224,843,042,201.5845
# Item_Identifier_FDP01              -2,224,843,041,620.0391
# Item_Identifier_FDQ49              -2,224,843,041,612.6050
# Item_Identifier_FDM25              -2,224,843,040,384.1353
# Item_Identifier_FDK25              -2,224,843,039,680.2251
# Item_Identifier_FDR37              -2,224,843,039,233.3311
# Item_Identifier_FDL13              -2,224,843,038,817.9414
# Outlet_Identifier_OUT018           -2,120,488,182,721.6592
# Item_Type_Canned                   -1,599,433,477,296.8745
# Outlet_Identifier_OUT019           -1,546,992,930,907.4009
# Item_Type_Starchy Foods            -1,508,432,344,020.9651
# Item_Identifier_FDQ22              -1,209,564,771,543.9143
# Item_Identifier_FDC58              -1,209,564,771,227.5188
# Item_Identifier_FDA57              -1,209,564,770,963.7517
# Item_Identifier_FDJ09              -1,209,564,770,928.7722
# Item_Identifier_FDT45              -1,209,564,770,562.5786
# Item_Identifier_FDT22              -1,209,564,770,527.8208
# Item_Identifier_FDT46              -1,209,564,770,487.6978
# Item_Identifier_FDF58              -1,209,564,770,157.7754
# Item_Identifier_FDH33              -1,209,564,770,036.8105
# Item_Identifier_FDZ22              -1,209,564,769,783.5781
# Item_Identifier_FDL22              -1,209,564,769,709.9116
# Item_Identifier_FDN10              -1,209,564,769,523.6401
# Item_Identifier_FDL10              -1,209,564,769,438.0630
# Item_Identifier_FDR58              -1,209,564,769,433.9978
# Item_Identifier_FDM46              -1,209,564,769,407.3420
# Item_Identifier_FDP57              -1,209,564,769,267.0864
# Item_Identifier_FDW33              -1,209,564,769,247.9722
# Item_Identifier_FDD58              -1,209,564,769,238.9048
# Item_Identifier_FDW58              -1,209,564,769,232.7268
# Item_Identifier_FDX21              -1,209,564,769,215.6143
# Item_Identifier_FDF46              -1,209,564,769,206.7793
# Item_Identifier_FDP10              -1,209,564,769,203.0779
# Item_Identifier_FDZ46              -1,209,564,769,195.4265
# Item_Identifier_FDQ34              -1,209,564,769,174.7920
# Item_Identifier_FDL46              -1,209,564,769,131.4622
# Item_Identifier_FDP46              -1,209,564,769,100.7522
# Item_Identifier_FDT34              -1,209,564,769,076.5088
# Item_Identifier_FDB34              -1,209,564,769,047.6323
# Item_Identifier_FDQ09              -1,209,564,768,903.8113
# Item_Identifier_FDA10              -1,209,564,768,879.5720
# Item_Identifier_FDI33              -1,209,564,768,874.0928
# Item_Identifier_FDE46              -1,209,564,768,862.7209
# Item_Identifier_FDQ46              -1,209,564,768,853.8196
# Item_Identifier_FDR33              -1,209,564,768,788.7415
# Item_Identifier_FDV46              -1,209,564,768,770.6956
# Item_Identifier_FDE58              -1,209,564,768,680.1160
# Item_Identifier_FDY10              -1,209,564,768,630.2649
# Item_Identifier_FDH22              -1,209,564,768,601.1157
# Item_Identifier_FDO33              -1,209,564,768,536.5962
# Item_Identifier_FDS57              -1,209,564,768,449.4387
# Item_Identifier_FDW45              -1,209,564,768,441.4265
# Item_Identifier_FDM34              -1,209,564,768,436.8027
# Item_Identifier_FDN21              -1,209,564,768,324.0220
# Item_Identifier_FDH10              -1,209,564,768,302.6873
# Item_Identifier_FDZ58              -1,209,564,768,298.8594
# Item_Identifier_FDH58              -1,209,564,768,261.5728
# Item_Identifier_FDY09              -1,209,564,768,254.2166
# Item_Identifier_FDU34              -1,209,564,768,237.8672
# Item_Identifier_FDR10              -1,209,564,768,231.6570
# Item_Identifier_FDV21              -1,209,564,768,221.7161
# Item_Identifier_FDZ10              -1,209,564,768,221.5608
# Item_Identifier_FDQ58              -1,209,564,768,214.5989
# Item_Identifier_FDJ22              -1,209,564,768,180.0269
# Item_Identifier_FDX34              -1,209,564,768,177.1255
# Item_Identifier_FDL45              -1,209,564,768,127.2554
# Item_Identifier_FDZ33              -1,209,564,768,095.8240
# Item_Identifier_FDD46              -1,209,564,768,086.2004
# Item_Identifier_FDQ21              -1,209,564,768,043.9988
# Item_Identifier_FDX45              -1,209,564,767,992.5911
# Item_Identifier_FDV09              -1,209,564,767,976.1909
# Item_Identifier_FDT58              -1,209,564,767,971.7898
# Item_Identifier_FDU22              -1,209,564,767,955.5149
# Item_Identifier_FDB22              -1,209,564,767,939.0254
# Item_Identifier_FDQ57              -1,209,564,767,925.4590
# Item_Identifier_FDD34              -1,209,564,767,842.0481
# Item_Identifier_FDA33              -1,209,564,767,833.2639
# Item_Identifier_FDR21              -1,209,564,767,829.4006
# Item_Identifier_FDO58              -1,209,564,767,799.4067
# Item_Identifier_FDR46              -1,209,564,767,785.0671
# Item_Identifier_FDP34              -1,209,564,767,781.4883
# Item_Identifier_FDN57              -1,209,564,767,716.9861
# Item_Identifier_FDE22              -1,209,564,767,713.8545
# Item_Identifier_FDJ46              -1,209,564,767,651.4338
# Item_Identifier_FDK57              -1,209,564,767,584.8962
# Item_Identifier_FDB59              -1,209,564,767,561.9365
# Item_Identifier_FDA45              -1,209,564,767,517.6279
# Item_Identifier_FDW10              -1,209,564,767,509.3262
# Item_Identifier_FDO57              -1,209,564,767,464.0586
# Item_Identifier_FDL34              -1,209,564,767,397.6477
# Item_Identifier_FDZ09              -1,209,564,767,361.8147
# Item_Identifier_FDV58              -1,209,564,767,342.1851
# Item_Identifier_FDD22              -1,209,564,767,224.9851
# Item_Identifier_FDB47              -1,209,564,767,220.5725
# Item_Identifier_FDA58              -1,209,564,767,204.3213
# Item_Identifier_FDB10              -1,209,564,767,137.9880
# Item_Identifier_FDL33              -1,209,564,767,034.7786
# Item_Identifier_FDK22              -1,209,564,766,988.0759
# Item_Identifier_FDA46              -1,209,564,766,983.0059
# Item_Identifier_FDQ10              -1,209,564,766,971.0574
# Item_Identifier_FDM10              -1,209,564,766,951.4951
# Item_Identifier_FDO34              -1,209,564,766,906.4648
# Item_Identifier_FDS10              -1,209,564,766,871.4978
# Item_Identifier_FDX09              -1,209,564,766,766.7817
# Item_Identifier_FDY46              -1,209,564,766,531.6257
# Item_Identifier_FDV45              -1,209,564,766,462.2131
# Item_Identifier_FDP58              -1,209,564,766,447.0957
# Item_Identifier_FDZ45              -1,209,564,766,408.1262
# Item_Identifier_FDY21              -1,209,564,766,382.3721
# Item_Identifier_FDH34              -1,209,564,766,297.2080
# Item_Identifier_FDE34              -1,209,564,766,296.5093
# Item_Identifier_FDC46              -1,209,564,766,278.8533
# Item_Identifier_FDA21              -1,209,564,766,211.7034
# Item_Identifier_FDT21              -1,209,564,766,210.1785
# Item_Identifier_FDN09              -1,209,564,766,207.5122
# Item_Identifier_FDQ33              -1,209,564,766,206.6074
# Item_Identifier_FDW34              -1,209,564,766,139.9724
# Item_Identifier_FDI22              -1,209,564,766,078.2087
# Item_Identifier_FDP09              -1,209,564,766,054.0808
# Item_Identifier_FDX58              -1,209,564,765,990.3267
# Item_Identifier_FDI46              -1,209,564,765,988.8384
# Item_Identifier_FDN45              -1,209,564,765,935.8430
# Item_Identifier_FDK09              -1,209,564,765,876.4978
# Item_Identifier_FDF22              -1,209,564,765,834.8706
# Item_Identifier_FDK33              -1,209,564,765,698.8115
# Item_Identifier_FDY45              -1,209,564,765,681.7500
# Item_Identifier_FDT57              -1,209,564,765,604.3848
# Item_Identifier_FDM33              -1,209,564,765,571.7708
# Item_Identifier_FDY58              -1,209,564,765,492.1365
# Item_Identifier_FDK34              -1,209,564,765,358.1294
# Item_Identifier_FDK21              -1,209,564,765,322.7192
# Item_Identifier_FDK46              -1,209,564,765,167.0579
# Item_Identifier_FDM21              -1,209,564,764,845.2136
# Item_Identifier_FDP33              -1,209,564,764,673.9294
# Item_Identifier_FDR09              -1,209,564,764,358.4312
# Item_Identifier_FDC47              -1,209,564,763,862.2454
# Item_Identifier_FDR45              -1,209,564,762,798.7964
# Item_Type_Breads                   -1,191,843,616,323.6152
# Item_Identifier_FDF09              -1,175,732,251,251.3669
# Item_Identifier_FDV43              -1,175,732,251,083.2673
# Item_Identifier_FDE32              -1,175,732,250,989.9995
# Item_Identifier_FDQ20              -1,175,732,250,926.3098
# Item_Identifier_FDT20              -1,175,732,250,848.8989
# Item_Identifier_FDD08              -1,175,732,250,714.6545
# Item_Identifier_FDV08              -1,175,732,250,712.5554
# Item_Identifier_FDJ32              -1,175,732,250,685.6316
# Item_Identifier_FDY07              -1,175,732,250,639.8638
# Item_Identifier_FDG57              -1,175,732,250,597.0581
# Item_Identifier_FDR43              -1,175,732,250,588.9209
# Item_Identifier_FDT43              -1,175,732,250,513.9812
# Item_Identifier_FDE44              -1,175,732,250,378.0615
# Item_Identifier_FDP56              -1,175,732,250,371.3289
# Item_Identifier_FDO32              -1,175,732,250,336.2876
# Item_Identifier_FDC20              -1,175,732,250,114.0801
# Item_Identifier_FDA44              -1,175,732,250,000.4236
# Item_Identifier_FDG44              -1,175,732,249,978.1948
# Item_Identifier_FDB20              -1,175,732,249,969.0300
# Item_Identifier_FDU08              -1,175,732,249,915.2822
# Item_Identifier_FDI44              -1,175,732,249,757.2146
# Item_Identifier_FDX44              -1,175,732,249,738.1570
# Item_Identifier_FDM56              -1,175,732,249,528.5852
# Item_Identifier_FDM32              -1,175,732,249,426.8281
# Item_Identifier_FDW08              -1,175,732,249,386.8210
# Item_Identifier_FDC32              -1,175,732,249,364.2065
# Item_Identifier_FDV32              -1,175,732,249,359.4785
# Item_Identifier_FDD57              -1,175,732,249,264.0659
# Item_Identifier_FDE09              -1,175,732,249,114.2214
# Item_Identifier_FDB32              -1,175,732,249,112.0508
# Item_Identifier_FDD45              -1,175,732,249,103.0056
# Item_Identifier_FDS07              -1,175,732,249,075.6362
# Item_Identifier_FDP20              -1,175,732,249,070.8943
# Item_Identifier_FDR07              -1,175,732,249,025.8054
# Item_Identifier_FDZ44              -1,175,732,249,016.4314
# Item_Identifier_FDM44              -1,175,732,249,002.8574
# Item_Identifier_FDQ56              -1,175,732,248,969.6523
# Item_Identifier_FDB09              -1,175,732,248,929.8201
# Item_Identifier_FDV07              -1,175,732,248,855.4709
# Item_Identifier_FDT44              -1,175,732,248,850.4651
# Item_Identifier_FDY43              -1,175,732,248,846.2400
# Item_Identifier_FDL56              -1,175,732,248,840.0310
# Item_Identifier_FDI56              -1,175,732,248,826.8574
# Item_Identifier_FDC44              -1,175,732,248,772.9976
# Item_Identifier_FDJ56              -1,175,732,248,768.7024
# Item_Identifier_FDO44              -1,175,732,248,731.7803
# Item_Identifier_FDE21              -1,175,732,248,684.3127
# Item_Identifier_FDR08              -1,175,732,248,634.6572
# Item_Identifier_FDB45              -1,175,732,248,606.1809
# Item_Identifier_FDH32              -1,175,732,248,380.4661
# Item_Identifier_FDD20              -1,175,732,248,377.4580
# Item_Identifier_FDP32              -1,175,732,248,367.8662
# Item_Identifier_FDU32              -1,175,732,248,357.7590
# Item_Identifier_FDW20              -1,175,732,248,331.6099
# Item_Identifier_FDH57              -1,175,732,248,317.2290
# Item_Identifier_FDL20              -1,175,732,248,241.7129
# Item_Identifier_FDA19              -1,175,732,248,170.9380
# Item_Identifier_FDX43              -1,175,732,248,131.7554
# Item_Identifier_FDI32              -1,175,732,248,076.6106
# Item_Identifier_FDS08              -1,175,732,248,044.6050
# Item_Identifier_FDB08              -1,175,732,247,981.3989
# Item_Identifier_FDY19              -1,175,732,247,951.3413
# Item_Identifier_FDC45              -1,175,732,247,926.8062
# Item_Identifier_FDF32              -1,175,732,247,906.9663
# Item_Identifier_FDQ44              -1,175,732,247,900.2754
# Item_Identifier_FDN44              -1,175,732,247,898.1946
# Item_Identifier_FDK44              -1,175,732,247,875.2327
# Item_Identifier_FDV55              -1,175,732,247,866.6072
# Item_Identifier_FDP19              -1,175,732,247,851.5371
# Item_Identifier_FDY31              -1,175,732,247,781.0637
# Item_Identifier_FDT08              -1,175,732,247,750.2849
# Item_Identifier_FDZ19              -1,175,732,247,742.6948
# Item_Identifier_FDA56              -1,175,732,247,731.6030
# Item_Identifier_FDU07              -1,175,732,247,712.8098
# Item_Identifier_FDA31              -1,175,732,247,664.5491
# Item_Identifier_FDV31              -1,175,732,247,615.2227
# Item_Identifier_FDN31              -1,175,732,247,553.7190
# Item_Identifier_FDE57              -1,175,732,247,528.8845
# Item_Identifier_FDC56              -1,175,732,247,486.3540
# Item_Identifier_FDS55              -1,175,732,247,470.1116
# Item_Identifier_FDE08              -1,175,732,247,326.4688
# Item_Identifier_FDF20              -1,175,732,247,267.9070
# Item_Identifier_FDX08              -1,175,732,247,182.0007
# Item_Identifier_FDS43              -1,175,732,247,123.9294
# Item_Identifier_FDZ55              -1,175,732,247,041.1934
# Item_Identifier_FDA43              -1,175,732,247,037.4429
# Item_Identifier_FDN20              -1,175,732,246,973.7329
# Item_Identifier_FDI45              -1,175,732,246,900.8403
# Item_Identifier_FDE45              -1,175,732,246,871.3289
# Item_Identifier_FDS20              -1,175,732,246,854.8030
# Item_Identifier_FDT31              -1,175,732,246,820.4482
# Item_Identifier_FDK56              -1,175,732,246,714.6316
# Item_Identifier_FDZ56              -1,175,732,246,636.4409
# Item_Identifier_FDB33              -1,175,732,246,554.9604
# Item_Identifier_FDY32              -1,175,732,246,475.9028
# Item_Identifier_FDL44              -1,175,732,246,466.4458
# Item_Identifier_FDA20              -1,175,732,246,442.2166
# Item_Identifier_FDP07              -1,175,732,246,436.5378
# Item_Identifier_FDJ08              -1,175,732,246,435.2632
# Item_Identifier_FDA32              -1,175,732,246,400.2107
# Item_Identifier_FDD09              -1,175,732,246,393.5435
# Item_Identifier_FDB44              -1,175,732,246,122.8628
# Item_Identifier_FDN32              -1,175,732,246,081.5510
# Item_Identifier_FDX20              -1,175,732,246,001.8469
# Item_Identifier_FDX55              -1,175,732,245,928.8638
# Item_Identifier_FDB21              -1,175,732,245,567.2742
# Item_Identifier_FDG32              -1,175,732,245,531.3030
# Item_Identifier_FDX19              -1,175,732,245,435.6528
# Item_Identifier_FDU56              -1,175,732,245,359.5410
# Item_Identifier_FDI20              -1,175,732,245,114.7974
# Item_Identifier_FDD33              -1,175,732,245,105.1182
# Item_Identifier_FDL08              -1,175,732,245,050.1738
# Item_Identifier_FDH08              -1,175,732,245,007.1768
# Item_Identifier_FDW56              -1,175,732,244,868.5486
# Item_Identifier_FDG45              -1,175,732,244,841.7554
# Item_Identifier_FDM20              -1,175,732,243,984.9688
# Item_Identifier_FDZ20              -1,175,732,243,896.2764
# Item_Identifier_FDU55              -1,175,732,242,630.1404
# Item_Identifier_FDY55              -1,175,732,242,411.6257
# Item_Type_Dairy                    -1,141,038,085,158.2693
# Outlet_Type_Supermarket Type2        -836,829,381,165.7206
# Item_Identifier_FDX10                -685,375,022,093.6458
# Item_Identifier_FDG22                -685,375,021,987.5320
# Item_Identifier_FDU21                -685,375,021,563.0439
# Item_Identifier_FDJ58                -685,375,018,124.4539
# Item_Identifier_FDT33                -685,375,018,036.6676
# Item_Identifier_FDK10                -685,375,017,958.7112
# Item_Identifier_FDL09                -685,375,017,928.0507
# Item_Identifier_FDV22                -685,375,017,884.7493
# Item_Identifier_FDJ33                -685,375,017,827.9307
# Item_Identifier_FDP45                -685,375,017,757.2855
# Item_Identifier_FDF34                -685,375,017,709.7880
# Item_Identifier_FDQ45                -685,375,017,579.5619
# Item_Identifier_FDJ21                -685,375,017,514.0240
# Item_Identifier_FDY33                -685,375,017,507.1597
# Item_Identifier_FDY34                -685,375,017,450.1635
# Item_Identifier_FDO21                -685,375,017,449.7771
# Item_Identifier_FDS58                -685,375,017,387.3849
# Item_Identifier_FDC22                -685,375,017,368.1766
# Item_Identifier_FDW57                -685,375,017,239.0575
# Item_Identifier_FDO46                -685,375,017,105.9189
# Item_Identifier_FDC34                -685,375,017,102.6412
# Item_Identifier_FDI10                -685,375,017,052.8561
# Item_Identifier_FDA09                -685,375,017,025.7733
# Item_Identifier_FDV57                -685,375,016,818.8879
# Item_Identifier_FDI34                -685,375,016,608.7905
# Item_Identifier_FDP21                -685,375,016,594.3173
# Item_Identifier_FDX22                -685,375,016,581.2747
# Item_Identifier_FDB46                -685,375,016,562.5830
# Item_Identifier_FDV33                -685,375,016,324.1582
# Item_Identifier_FDN22                -685,375,016,198.5902
# Item_Identifier_FDL58                -685,375,016,089.8912
# Item_Identifier_FDW22                -685,375,015,686.6379
# Item_Identifier_FDO09                -685,375,015,319.0613
# Item_Identifier_FDN58                -685,375,015,317.3090
# Item_Identifier_FDL57                -685,375,014,884.6692
# Item_Identifier_FDR34                -685,375,014,482.4250
# Item_Identifier_FDH45                -651,542,500,896.7587
# Item_Identifier_FDT56                -651,542,500,893.3657
# Item_Identifier_FDR20                -651,542,500,776.8574
# Item_Identifier_FDP31                -651,542,500,689.3357
# Item_Identifier_FDO19                -651,542,500,645.7161
# Item_Identifier_FDE56                -651,542,500,545.9681
# Item_Identifier_FDV56                -651,542,500,543.5732
# Item_Identifier_FDZ08                -651,542,500,431.4698
# Item_Identifier_FDG56                -651,542,500,357.5052
# Item_Identifier_FDQ08                -651,542,500,347.5789
# Item_Identifier_FDO31                -651,542,500,330.7412
# Item_Identifier_FDD32                -651,542,500,250.6304
# Item_Identifier_FDF45                -651,542,500,247.5179
# Item_Identifier_FDZ07                -651,542,500,236.0225
# Item_Identifier_FDS19                -651,542,500,019.0803
# Item_Identifier_FDW07                -651,542,499,845.6577
# Item_Identifier_FDY20                -651,542,499,841.0466
# Item_Identifier_FDQ31                -651,542,499,823.4044
# Item_Identifier_FDE33                -651,542,499,797.9032
# Item_Identifier_FDC09                -651,542,499,792.3894
# Item_Identifier_FDW32                -651,542,499,701.4742
# Item_Identifier_FDF08                -651,542,499,594.3195
# Item_Identifier_FDK08                -651,542,499,546.5524
# Item_Identifier_FDO56                -651,542,499,543.3021
# Item_Identifier_FDC21                -651,542,499,523.5758
# Item_Identifier_FDH20                -651,542,499,498.5254
# Item_Identifier_FDR44                -651,542,499,492.8488
# Item_Identifier_FDZ32                -651,542,499,481.3018
# Item_Identifier_FDP44                -651,542,499,314.5001
# Item_Identifier_FDW19                -651,542,499,298.0320
# Item_Identifier_FDL32                -651,542,499,271.5405
# Item_Identifier_FDH56                -651,542,499,131.2135
# Item_Identifier_FDN08                -651,542,499,117.1405
# Item_Identifier_FDQ55                -651,542,499,070.6536
# Item_Identifier_FDJ20                -651,542,498,917.7572
# Item_Identifier_FDQ32                -651,542,498,890.0585
# Item_Identifier_FDA07                -651,542,498,886.8367
# Item_Identifier_FDU20                -651,542,498,845.2208
# Item_Identifier_FDY08                -651,542,498,659.7959
# Item_Identifier_FDR31                -651,542,498,648.9060
# Item_Identifier_FDH44                -651,542,498,610.6501
# Item_Identifier_FDV44                -651,542,498,512.2985
# Item_Identifier_FDS32                -651,542,498,510.7141
# Item_Identifier_FDV20                -651,542,498,475.0038
# Item_Identifier_FDK20                -651,542,498,471.5919
# Item_Identifier_FDG20                -651,542,498,467.6794
# Item_Identifier_FDF57                -651,542,498,402.1177
# Item_Identifier_FDD21                -651,542,498,384.2056
# Item_Identifier_FDO08                -651,542,498,288.4027
# Item_Identifier_FDU19                -651,542,498,159.8844
# Item_Identifier_FDW44                -651,542,498,141.2224
# Item_Identifier_FDJ44                -651,542,498,135.6598
# Item_Identifier_FDA08                -651,542,498,088.7090
# Item_Identifier_FDR19                -651,542,498,020.0527
# Item_Identifier_FDX32                -651,542,498,013.2153
# Item_Identifier_FDN56                -651,542,497,715.6715
# Item_Identifier_FDS31                -651,542,497,680.6371
# Item_Identifier_FDF44                -651,542,497,651.4948
# Item_Identifier_FDU44                -651,542,497,629.3979
# Item_Identifier_FDT32                -651,542,497,556.9537
# Item_Identifier_FDE20                -651,542,497,501.0873
# Item_Identifier_FDC33                -651,542,497,476.8829
# Item_Identifier_FDU43                -651,542,497,459.9355
# Item_Identifier_FDW31                -651,542,497,405.4924
# Item_Identifier_FDG08                -651,542,497,399.9708
# Item_Identifier_FDV19                -651,542,497,217.7849
# Item_Identifier_FDD56                -651,542,497,173.1815
# Item_Identifier_FDQ07                -651,542,497,129.0432
# Item_Identifier_FDY44                -651,542,497,116.0989
# Item_Identifier_FDX07                -651,542,497,104.6395
# Item_Identifier_FDU31                -651,542,497,043.4551
# Item_Identifier_FDT55                -651,542,497,005.0370
# Item_Identifier_FDT19                -651,542,496,912.3854
# Item_Identifier_FDK32                -651,542,496,905.0065
# Item_Identifier_FDP08                -651,542,496,893.8790
# Item_Identifier_FDF56                -651,542,496,865.9479
# Item_Identifier_FDC57                -651,542,496,828.1694
# Item_Identifier_FDZ31                -651,542,496,828.0115
# Item_Identifier_FDR55                -651,542,496,776.7396
# Item_Identifier_FDG09                -651,542,496,719.7450
# Item_Identifier_FDC08                -651,542,496,564.4080
# Item_Identifier_FDM08                -651,542,496,525.3071
# Item_Identifier_FDB56                -651,542,496,507.2108
# Item_Identifier_FDB57                -651,542,496,454.1473
# Item_Identifier_FDF21                -651,542,496,373.0554
# Item_Identifier_FDR56                -651,542,496,350.2864
# Item_Identifier_FDX56                -651,542,496,297.2012
# Item_Identifier_FDR32                -651,542,496,153.5625
# Item_Identifier_FDW43                -651,542,496,083.6390
# Item_Identifier_FDO20                -651,542,495,877.0385
# Item_Identifier_FDY56                -651,542,495,867.7974
# Item_Identifier_FDT07                -651,542,495,797.9799
# Item_Identifier_FDS44                -651,542,495,792.1455
# Item_Identifier_FDX31                -651,542,495,746.4637
# Item_Identifier_FDA55                -651,542,495,640.8754
# Item_Identifier_FDI08                -651,542,495,580.0099
# Item_Identifier_FDS56                -651,542,495,548.6552
# Item_Identifier_FDZ43                -651,542,495,310.0812
# Item_Identifier_FDW55                -651,542,495,015.7144
# Item_Identifier_FDQ19                -651,542,494,781.4724
# Item_Identifier_FDD44                -651,542,493,740.6320
# Item_Type_Frozen Foods               -647,049,250,124.3218
# Item_Type_Soft Drinks                -568,963,774,007.7424
# Item_Type_Household                  -388,077,959,750.7317
# Item_Identifier_DRN59                -303,538,528,142.1804
# Item_Identifier_DRJ35                -303,538,528,044.7398
# Item_Identifier_DRJ59                -303,538,528,032.1254
# Item_Identifier_DRN35                -303,538,527,817.6062
# Item_Identifier_DRL35                -303,538,527,741.8837
# Item_Identifier_DRK35                -303,538,527,731.7247
# Item_Identifier_DRH11                -303,538,527,610.7548
# Item_Identifier_DRL59                -303,538,527,384.8721
# Item_Identifier_DRH23                -303,538,527,111.6093
# Item_Identifier_DRH59                -303,538,526,988.4254
# Item_Identifier_DRO59                -303,538,526,781.9832
# Item_Identifier_DRL47                -303,538,526,727.5847
# Item_Identifier_DRL23                -303,538,526,193.9979
# Item_Identifier_DRI11                -303,538,526,043.1592
# Item_Identifier_DRO47                -303,538,525,970.5996
# Item_Identifier_DRG11                -303,538,525,845.0973
# Item_Identifier_DRK11                -303,538,525,737.4207
# Item_Identifier_DRG23                -303,538,525,680.5808
# Item_Identifier_DRP35                -303,538,525,418.5331
# Item_Identifier_DRQ35                -303,538,525,220.3731
# Item_Identifier_DRN11                -303,538,525,121.7940
# Item_Identifier_DRM59                -303,538,525,051.5601
# Item_Identifier_DRI47                -303,538,524,891.5532
# Item_Identifier_DRI23                -303,538,524,767.0046
# Item_Identifier_DRM23                -303,538,524,492.6642
# Item_Identifier_DRL11                -303,538,524,430.2872
# Item_Identifier_DRN47                -303,538,524,370.0417
# Item_Identifier_DRK59                -303,538,524,043.3837
# Item_Identifier_DRF23                -303,538,523,913.9736
# Item_Identifier_DRJ23                -303,538,523,906.0401
# Item_Identifier_DRM47                -303,538,523,846.4794
# Item_Identifier_DRJ11                -303,538,523,258.3742
# Item_Identifier_DRJ47                -303,538,523,227.5339
# Item_Identifier_DRK47                -303,538,523,167.6320
# Item_Identifier_DRM11                -303,538,522,511.2538
# Item_Identifier_DRP47                -303,538,522,108.0702
# Item_Identifier_DRI59                -303,538,522,017.2415
# Item_Identifier_DRM35                -303,538,521,831.1008
# Item_Identifier_DRK23                -303,538,520,701.3640
# Item_Fat_Content_Regular             -262,094,874,757.8607
# Item_Identifier_FDZ01               1,773,545,218,724.4585
# Item_Identifier_FDD38               1,773,545,218,783.1448
# Item_Identifier_FDG38               1,773,545,218,790.5171
# Item_Identifier_FDL38               1,773,545,218,801.6738
# Item_Identifier_FDY01               1,773,545,218,810.1499
# Item_Identifier_FDE14               1,773,545,218,885.8059
# Item_Identifier_FDA25               1,773,545,218,934.5293
# Item_Identifier_FDB14               1,773,545,218,976.7981
# Item_Identifier_FDU49               1,773,545,219,172.7078
# Item_Identifier_FDJ02               1,773,545,219,280.5630
# Item_Identifier_FDS25               1,773,545,219,290.8167
# Item_Identifier_FDL14               1,773,545,219,312.5400
# Item_Identifier_FDH26               1,773,545,219,438.9380
# Item_Identifier_FDL02               1,773,545,219,463.7163
# Item_Identifier_FDA37               1,773,545,219,468.8894
# Item_Identifier_FDY49               1,773,545,219,679.1477
# Item_Identifier_FDH14               1,773,545,219,739.8823
# Item_Identifier_FDV01               1,773,545,219,774.1892
# Item_Identifier_FDY37               1,773,545,220,089.4412
# Item_Identifier_FDF26               1,773,545,220,121.2861
# Item_Identifier_FDR25               1,773,545,220,139.5061
# Item_Identifier_FDB38               1,773,545,220,195.0312
# Item_Identifier_FDQ25               1,773,545,220,430.3137
# Item_Identifier_FDU01               1,773,545,220,491.1619
# Item_Identifier_FDJ26               1,773,545,220,832.9924
# Item_Identifier_FDZ25               1,773,545,220,981.6643
# Item_Identifier_FDH50               1,773,545,220,994.8005
# Item_Identifier_FDE50               1,773,545,221,041.4668
# Item_Identifier_FDD26               1,773,545,221,079.8752
# Item_Identifier_FDB02               1,773,545,221,301.0488
# Item_Identifier_FDV37               1,773,545,221,379.5776
# Item_Identifier_FDR01               1,773,545,221,382.2024
# Item_Identifier_FDG14               1,773,545,221,394.2092
# Item_Identifier_FDT01               1,773,545,221,623.1736
# Item_Identifier_FDK26               1,773,545,221,678.4795
# Item_Identifier_FDJ38               1,773,545,221,796.4048
# Item_Identifier_FDI38               1,773,545,222,177.4487
# Item_Identifier_FDZ49               1,773,545,222,369.6636
# Item_Identifier_FDX49               1,773,545,222,514.3389
# Item_Identifier_FDQ01               1,773,545,222,516.1514
# Item_Identifier_FDN38               1,773,545,222,985.3523
# Item_Identifier_FDI50               1,773,545,222,993.0457
# Item_Identifier_NCY41               1,905,654,797,374.6907
# Item_Identifier_NCD42               1,905,654,797,391.4084
# Item_Identifier_NCY05               1,905,654,797,515.8245
# Item_Identifier_NCZ17               1,905,654,797,629.4404
# Item_Identifier_NCL41               1,905,654,797,636.6506
# Item_Identifier_NCK17               1,905,654,797,711.0417
# Item_Identifier_NCL05               1,905,654,797,825.4775
# Item_Identifier_NCM17               1,905,654,797,869.3411
# Item_Identifier_NCN53               1,905,654,797,948.5664
# Item_Identifier_NCA53               1,905,654,797,955.9648
# Item_Identifier_NCY17               1,905,654,797,989.5010
# Item_Identifier_NCR29               1,905,654,798,013.4004
# Item_Identifier_NCP17               1,905,654,798,079.3760
# Item_Identifier_NCN29               1,905,654,798,130.0383
# Item_Identifier_NCY29               1,905,654,798,211.1790
# Item_Identifier_NCP29               1,905,654,798,246.6213
# Item_Identifier_NCU17               1,905,654,798,284.8225
# Item_Identifier_NCK05               1,905,654,798,434.8840
# Item_Identifier_NCU05               1,905,654,798,437.0332
# Item_Identifier_NCJ29               1,905,654,798,514.9443
# Item_Identifier_NCM41               1,905,654,798,698.8728
# Item_Identifier_NCZ05               1,905,654,798,971.4832
# Item_Identifier_NCJ17               1,905,654,798,980.8059
# Item_Identifier_NCN17               1,905,654,799,012.7571
# Item_Identifier_NCI17               1,905,654,799,171.8013
# Item_Identifier_NCO41               1,905,654,799,251.1311
# Item_Identifier_NCP41               1,905,654,799,302.2524
# Item_Identifier_NCV41               1,905,654,799,330.0269
# Item_Identifier_NCR41               1,905,654,799,357.3826
# Item_Identifier_NCX05               1,905,654,799,378.3188
# Item_Identifier_NCB54               1,905,654,799,431.8364
# Item_Identifier_NCH29               1,905,654,799,434.4919
# Item_Identifier_NCO05               1,905,654,799,483.7205
# Item_Identifier_NCM53               1,905,654,799,509.7141
# Item_Identifier_NCS17               1,905,654,799,534.2927
# Item_Identifier_NCY53               1,905,654,799,549.1965
# Item_Identifier_NCI29               1,905,654,799,586.0256
# Item_Identifier_NCA05               1,905,654,799,587.5762
# Item_Identifier_NCB42               1,905,654,799,656.0889
# Item_Identifier_NCS05               1,905,654,799,684.4668
# Item_Identifier_NCZ41               1,905,654,799,752.7852
# Item_Identifier_NCK53               1,905,654,799,791.0017
# Item_Identifier_NCT29               1,905,654,799,814.3860
# Item_Identifier_NCS41               1,905,654,799,904.0779
# Item_Identifier_NCR17               1,905,654,800,006.4758
# Item_Identifier_NCN41               1,905,654,800,010.9460
# Item_Identifier_NCC42               1,905,654,800,090.1626
# Item_Identifier_NCO17               1,905,654,800,099.7922
# Item_Identifier_NCK29               1,905,654,800,114.4978
# Item_Identifier_NCS53               1,905,654,800,116.4016
# Item_Identifier_NCW29               1,905,654,800,147.3066
# Item_Identifier_NCZ29               1,905,654,800,174.4583
# Item_Identifier_NCX29               1,905,654,800,195.2427
# Item_Identifier_NCV05               1,905,654,800,214.8059
# Item_Identifier_NCT41               1,905,654,800,260.7402
# Item_Identifier_NCU53               1,905,654,800,337.1699
# Item_Identifier_NCJ05               1,905,654,800,393.4856
# Item_Identifier_NCQ05               1,905,654,800,516.8450
# Item_Identifier_NCA17               1,905,654,800,677.7732
# Item_Identifier_NCV17               1,905,654,800,720.7761
# Item_Identifier_NCW17               1,905,654,800,731.2869
# Item_Identifier_NCL17               1,905,654,800,859.7776
# Item_Identifier_NCQ17               1,905,654,800,871.0051
# Item_Identifier_NCW53               1,905,654,800,872.1572
# Item_Identifier_NCM29               1,905,654,800,901.0405
# Item_Identifier_NCU29               1,905,654,800,901.4883
# Item_Identifier_NCT53               1,905,654,800,905.6484
# Item_Identifier_NCO29               1,905,654,800,931.8767
# Item_Identifier_NCL29               1,905,654,800,987.1357
# Item_Identifier_NCB06               1,905,654,801,041.2056
# Item_Identifier_NCW41               1,905,654,801,071.1611
# Item_Identifier_NCN05               1,905,654,801,074.8518
# Item_Identifier_NCP05               1,905,654,801,110.0103
# Item_Identifier_NCX53               1,905,654,801,153.0752
# Item_Identifier_NCV29               1,905,654,801,205.4919
# Item_Identifier_NCQ29               1,905,654,801,492.4292
# Item_Identifier_NCQ41               1,905,654,801,560.5801
# Item_Identifier_NCR05               1,905,654,801,904.9409
# Item_Identifier_NCX41               1,905,654,801,945.5911
# Item_Identifier_NCL53               1,905,654,801,987.5000
# Item_Identifier_NCO53               1,905,654,801,995.2710
# Item_Identifier_NCZ53               1,905,654,802,014.2156
# Item_Identifier_NCA41               1,905,654,802,018.9897
# Item_Identifier_NCT17               1,905,654,802,196.0667
# Item_Identifier_NCX17               1,905,654,802,654.4070
# Item_Identifier_NCT05               1,905,654,802,840.0835
# Item_Identifier_NCR53               1,905,654,802,866.0083
# Item_Identifier_NCS29               1,905,654,802,989.8157
# Item_Identifier_NCU41               1,905,654,803,137.7261
# Item_Identifier_NCP53               1,905,654,803,183.6311
# Item_Identifier_NCC54               1,905,654,803,377.6565
# Item_Identifier_NCM05               1,905,654,803,404.8826
# Item_Identifier_NCQ53               1,905,654,804,204.8625
# Item_Identifier_NCV53               1,905,654,804,554.5605
# Item_Identifier_FDK36               2,083,536,761,956.4766
# Item_Identifier_FDW23               2,083,536,761,977.7241
# Item_Identifier_FDO60               2,083,536,762,093.3247
# Item_Identifier_FDT36               2,083,536,762,171.5732
# Item_Identifier_FDR60               2,083,536,762,412.2014
# Item_Identifier_FDW24               2,083,536,762,413.6389
# Item_Identifier_FDK24               2,083,536,762,646.3145
# Item_Identifier_FDW48               2,083,536,762,651.3870
# Item_Identifier_FDY36               2,083,536,762,768.2437
# Item_Identifier_FDY59               2,083,536,762,965.2173
# Item_Identifier_FDK48               2,083,536,762,986.7781
# Item_Identifier_FDG24               2,083,536,763,174.7112
# Item_Identifier_FDX23               2,083,536,763,197.6572
# Item_Identifier_FDN24               2,083,536,763,229.6584
# Item_Identifier_FDZ60               2,083,536,763,260.7288
# Item_Identifier_FDX60               2,083,536,763,261.3967
# Item_Identifier_FDL36               2,083,536,763,314.0027
# Item_Identifier_FDA11               2,083,536,763,373.2585
# Item_Identifier_FDH48               2,083,536,763,433.4773
# Item_Identifier_FDN48               2,083,536,763,501.0090
# Item_Identifier_FDP60               2,083,536,763,562.1738
# Item_Identifier_FDC48               2,083,536,763,649.2634
# Item_Identifier_FDU48               2,083,536,763,715.1282
# Item_Identifier_FDA23               2,083,536,763,716.2932
# Item_Identifier_FDU36               2,083,536,763,727.8926
# Item_Identifier_FDW36               2,083,536,763,839.8721
# Item_Identifier_FDH12               2,083,536,763,911.4727
# Item_Identifier_FDY48               2,083,536,763,912.1626
# Item_Identifier_FDD36               2,083,536,763,944.7749
# Item_Identifier_FDZ48               2,083,536,763,952.2500
# Item_Identifier_FDX24               2,083,536,763,980.5188
# Item_Identifier_FDN12               2,083,536,764,001.3782
# Item_Identifier_FDP24               2,083,536,764,124.5369
# Item_Identifier_FDT60               2,083,536,764,214.5671
# Item_Identifier_FDD48               2,083,536,764,432.9998
# Item_Identifier_FDR48               2,083,536,764,445.5566
# Item_Identifier_FDS48               2,083,536,764,481.2227
# Item_Identifier_FDS12               2,083,536,764,594.8030
# Item_Identifier_FDE24               2,083,536,764,645.8801
# Item_Identifier_FDA36               2,083,536,764,732.2012
# Item_Identifier_FDV24               2,083,536,764,757.0764
# Item_Identifier_FDF12               2,083,536,764,883.3000
# Item_Identifier_FDV36               2,083,536,764,928.3694
# Item_Identifier_FDO36               2,083,536,765,128.9417
# Item_Identifier_FDH24               2,083,536,765,205.6687
# Item_Identifier_FDO24               2,083,536,765,259.3445
# Item_Identifier_FDS60               2,083,536,765,334.6677
# Item_Identifier_FDC37               2,083,536,765,338.4202
# Item_Identifier_FDZ12               2,083,536,765,688.5684
# Item_Identifier_FDN60               2,083,536,765,709.0225
# Item_Identifier_FDT48               2,083,536,766,078.3306
# Item_Identifier_FDQ12               2,083,536,766,259.2771
# Item_Identifier_FDO12               2,083,536,766,265.9021
# Item_Identifier_FDB60               2,083,536,766,540.3342
# Item_Identifier_FDI24               2,083,536,767,059.8711
# Item_Identifier_FDJ48               2,083,536,767,454.8347
# Item_Identifier_FDQ24               2,083,536,768,131.9451
# Item_Identifier_FDG60               2,083,536,768,216.6677
# Item_Identifier_FDA48               2,083,536,768,580.9858
# Item_Type_Breakfast                 2,398,954,783,815.0581
# Item_Type_Meat                      2,454,828,300,192.3701
# Item_Identifier_FDP12               2,607,726,511,286.9961
# Item_Identifier_FDM60               2,607,726,511,585.3872
# Item_Identifier_FDL48               2,607,726,511,638.9453
# Item_Identifier_FDI48               2,607,726,511,726.5425
# Item_Identifier_FDQ36               2,607,726,511,952.9780
# Item_Identifier_FDL12               2,607,726,512,018.2524
# Item_Identifier_FDR36               2,607,726,512,100.5137
# Item_Identifier_FDY12               2,607,726,512,174.0010
# Item_Identifier_FDY11               2,607,726,512,231.4604
# Item_Identifier_FDP36               2,607,726,512,324.1904
# Item_Identifier_FDY24               2,607,726,512,343.0703
# Item_Identifier_FDI60               2,607,726,512,478.1436
# Item_Identifier_FDQ48               2,607,726,512,542.4683
# Item_Identifier_FDS24               2,607,726,512,547.3755
# Item_Identifier_FDR24               2,607,726,512,624.7222
# Item_Identifier_FDV48               2,607,726,512,769.8027
# Item_Identifier_FDT24               2,607,726,512,924.6138
# Item_Identifier_FDK60               2,607,726,512,984.8735
# Item_Identifier_FDM12               2,607,726,512,999.8242
# Item_Identifier_FDZ47               2,607,726,513,006.6016
# Item_Identifier_FDF24               2,607,726,513,056.9321
# Item_Identifier_FDI12               2,607,726,513,097.6841
# Item_Identifier_FDB12               2,607,726,513,429.6934
# Item_Identifier_FDU24               2,607,726,513,432.9424
# Item_Identifier_FDV12               2,607,726,513,463.2080
# Item_Identifier_FDJ36               2,607,726,513,535.8936
# Item_Identifier_FDC60               2,607,726,513,595.3530
# Item_Identifier_FDS36               2,607,726,513,631.9487
# Item_Identifier_FDB36               2,607,726,513,702.6211
# Item_Identifier_FDB49               2,607,726,513,787.7407
# Item_Identifier_FDA35               2,607,726,513,871.9331
# Item_Identifier_FDQ60               2,607,726,513,883.2139
# Item_Identifier_FDG12               2,607,726,513,942.9897
# Item_Identifier_FDM24               2,607,726,514,069.8545
# Item_Identifier_FDY60               2,607,726,514,215.1304
# Item_Identifier_FDW12               2,607,726,514,216.5527
# Item_Identifier_FDW60               2,607,726,514,388.1313
# Item_Identifier_FDX48               2,607,726,514,466.1538
# Item_Identifier_FDJ60               2,607,726,514,722.2495
# Item_Identifier_FDR12               2,607,726,514,867.0234
# Item_Identifier_FDM36               2,607,726,514,973.8257
# Item_Identifier_FDA47               2,607,726,515,146.2373
# Item_Identifier_FDZ36               2,607,726,515,532.0059
# Item_Identifier_FDZ59               2,607,726,515,652.6689
# Item_Identifier_FDX11               2,607,726,515,696.3750
# Item_Identifier_FDJ12               2,607,726,515,727.8804
# Item_Identifier_FDI36               2,607,726,515,820.5308
# Item_Identifier_FDV60               2,607,726,515,923.9448
# Item_Identifier_FDH60               2,607,726,516,025.1934
# Item_Identifier_FDE36               2,607,726,516,167.9341
# Item_Identifier_FDO48               2,607,726,516,249.2734
# Item_Identifier_FDZ23               2,607,726,516,250.6001
# Item_Identifier_FDU12               2,607,726,516,616.8218
# Item_Identifier_FDP48               2,607,726,516,706.1055
# Item_Identifier_FDU60               2,607,726,516,709.6455
# Item_Identifier_FDT12               2,607,726,516,802.5464
# Item_Identifier_FDL24               2,607,726,516,868.7778
# Item_Identifier_FDX36               2,607,726,516,965.6958
# Item_Identifier_FDX12               2,607,726,517,173.4653
# Item_Identifier_FDB37               2,607,726,518,165.6938
# Item_Type_Others                    2,683,261,038,261.7139
# Outlet_Size_Small                   2,852,925,727,287.8613
# Item_Type_Seafood                   5,969,477,146,125.3027
# Outlet_Identifier_OUT013            6,611,813,700,238.7676
# Outlet_Type_Grocery Store           8,393,005,830,527.7949
# Outlet_Size_High                    9,954,342,450,357.1074
# Outlet_Identifier_OUT046           11,892,771,049,710.6484
# Outlet_Size_Medium                 14,536,567,023,831.8809
# intercept                          15,302,931,823,265.5215
# dtype: float64

# %%
## rank the coeffs and select the top_n
top_n=15
coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
top_n_features = coeff_rank.head(top_n)
coeffs_plot = coeffs.loc[top_n_features.index].sort_values()
coeffs_plot
# Out:
# Outlet_Location_Type_Tier 3   -23,257,681,116,380.1641
# Outlet_Location_Type_Tier 1   -21,419,618,372,825.2656
# Item_Identifier_FDH09          -6,319,555,156,111.4072
# Item_Identifier_FDJ45          -6,319,555,156,065.3770
# Item_Identifier_FDK45          -6,319,555,154,136.5098
# Item_Identifier_FDF33          -6,319,555,153,621.1895
# Item_Identifier_FDH21          -6,319,555,152,827.8652
# Item_Identifier_FDI57          -6,319,555,150,650.1846
# Item_Type_Seafood               5,969,477,146,125.3027
# Outlet_Identifier_OUT013        6,611,813,700,238.7676
# Outlet_Type_Grocery Store       8,393,005,830,527.7949
# Outlet_Size_High                9,954,342,450,357.1074
# Outlet_Identifier_OUT046       11,892,771,049,710.6484
# Outlet_Size_Medium             14,536,567,023,831.8809
# intercept                      15,302,931,823,265.5215
# dtype: float64

# %%
#plot coeffs with function
lr_plot = plot_coeffs(coeffs,top_n=15,intercept=False,annotate=True);
fig=lr_plot.get_figure()
fig.savefig('Images/Top 15 with Linear Regression')

# %% [markdown]
# ### Three most impactful coefficients:¶

# %% [markdown]
# - Outlet size: the size of the outlet affect grocery sales
# - Outlet identifier- this is a not useful index
# - Outlet type: similar to size but differences between a grocery store and an outlet

# %% [markdown]
# ### address coefficients with multicollinearity

# %% [markdown]
# ## Drop Coefficients without Outlet Identifier

# %%
## Get a list of all of the outlet identifier columns
outid_feats = [c for c in X_train_df.columns if c.startswith('Outlet_Identifier')]
len(outid_feats)
# Out:
# 10

# %%
## Make x and y variables
target = "Item_Outlet_Sales"
drop_feats = ["Outlet_Identifier", "Item_Identifier"]

y = df[target].copy()
X = df.drop(columns=[target, *drop_feats]).copy()

## train-test-split with random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=SEED)

## Make numeric preprocessing pipeline
num_sel = make_column_selector(dtype_include='number')
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))


## Make categorical preprocessing pipeline
cat_sel = make_column_selector(dtype_include='object')
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))

# %%
# run prerpocessor
preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=feature_names,
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=feature_names,
                         index=X_test.index)

# %%
#evaluate without  outlet identifier
lin_reg2= LinearRegression(fit_intercept=False)
lin_reg2.fit(X_train_df,y_train)
evaluate_regression(lin_reg2, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f068b">
#   <thead>
#     <tr>
#       <th id="T_f068b_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_f068b_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_f068b_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_f068b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f068b_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_f068b_row0_col1" class="data row0 col1" >0.56</td>
#       <td id="T_f068b_row0_col2" class="data row0 col2" >826.79</td>
#       <td id="T_f068b_row0_col3" class="data row0 col3" >1,114.98</td>
#     </tr>
#     <tr>
#       <td id="T_f068b_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_f068b_row1_col1" class="data row1 col1" >0.56</td>
#       <td id="T_f068b_row1_col2" class="data row1 col2" >859.97</td>
#       <td id="T_f068b_row1_col3" class="data row1 col3" >1,164.41</td>
#     </tr>
#   </tbody>
# </table>

# %%
#visualize coefficients (manually)
coeffs2 = pd.Series(lin_reg2.coef_, index=feature_names,
                        name='Coefficients')
coeffs2.loc['intercept'] = lin_reg.intercept_
coeffs2.head()
# Out:
# Item_Weight                       1.0679
# Item_Visibility                -276.6116
# Item_MRP                         15.6019
# Outlet_Establishment_Year        36.3821
# Item_Fat_Content_Low Fat    -25,976.1199
# Name: Coefficients, dtype: float64

# %%
lr_plot = plot_coeffs(coeffs2,top_n=15,intercept=False,annotate=True);
fig=lr_plot.get_figure()
fig.savefig('Images/Top 15 with Linear Regression_no Outlet Indentifier')

# %% [markdown]
# ## Random Forest Model

# %%
# instantiate the model, fit and evaluate
rf_reg = RandomForestRegressor()
rf_reg.fit(X_train_df,y_train)
evaluate_regression(rf_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2c96b">
#   <thead>
#     <tr>
#       <th id="T_2c96b_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_2c96b_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_2c96b_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_2c96b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2c96b_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_2c96b_row0_col1" class="data row0 col1" >0.94</td>
#       <td id="T_2c96b_row0_col2" class="data row0 col2" >294.49</td>
#       <td id="T_2c96b_row0_col3" class="data row0 col3" >426.73</td>
#     </tr>
#     <tr>
#       <td id="T_2c96b_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_2c96b_row1_col1" class="data row1 col1" >0.56</td>
#       <td id="T_2c96b_row1_col2" class="data row1 col2" >819.10</td>
#       <td id="T_2c96b_row1_col3" class="data row1 col3" >1,167.93</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Saving the coefficients
importances = pd.Series(rf_reg.feature_importances_, index= rf_reg.feature_names_in_)
importances
# Out:
# Item_Weight                       0.0536
# Item_Visibility                   0.0993
# Item_MRP                          0.4466
# Outlet_Establishment_Year         0.0381
# Item_Fat_Content_Low Fat          0.0047
# Item_Fat_Content_Regular          0.0049
# Item_Type_Baking Goods            0.0046
# Item_Type_Breads                  0.0030
# Item_Type_Breakfast               0.0025
# Item_Type_Canned                  0.0042
# Item_Type_Dairy                   0.0056
# Item_Type_Frozen Foods            0.0058
# Item_Type_Fruits and Vegetables   0.0084
# Item_Type_Hard Drinks             0.0029
# Item_Type_Health and Hygiene      0.0044
# Item_Type_Household               0.0062
# Item_Type_Meat                    0.0037
# Item_Type_Others                  0.0016
# Item_Type_Seafood                 0.0014
# Item_Type_Snack Foods             0.0080
# Item_Type_Soft Drinks             0.0042
# Item_Type_Starchy Foods           0.0029
# Outlet_Size_High                  0.0022
# Outlet_Size_MISSING               0.0051
# Outlet_Size_Medium                0.0047
# Outlet_Size_Small                 0.0066
# Outlet_Location_Type_Tier 1       0.0044
# Outlet_Location_Type_Tier 2       0.0034
# Outlet_Location_Type_Tier 3       0.0031
# Outlet_Type_Grocery Store         0.1968
# Outlet_Type_Supermarket Type1     0.0023
# Outlet_Type_Supermarket Type2     0.0015
# Outlet_Type_Supermarket Type3     0.0533
# dtype: float64

# %%
# Create plot
ax = importances.sort_values().tail(20).plot(kind='barh')#,figsize=(6,4))
ax.axvline(0, color='k')
ax.set(title='Feature Importance - Random Forest Tree Regressor',ylabel="Feature Name",
      xlabel='Importance');
fig.savefig('Images/Feature Importance with Random Forest')

# %%
#save image
rf_plot = plot_coeffs(coeffs,top_n=15,intercept=False,annotate=True);
fig=rf_plot.get_figure()
fig.savefig('Images/Top 15 with Random Forest')

# %% [markdown]
# # Export Data Using Joblib

# %%
import joblib, os

## creating a dictionary of all of the variables to save for later
export = {'X_train':X_train,
         'y_train':y_train,
         'X_test':X_test,
         'y_test':y_test,
          'preprocessor':preprocessor,
         'LinearRegression': lin_reg,
          'RandomForestRegressor':rf_reg
         }

# %%
#create folder
folder = "Models/"
os.makedirs(folder, exist_ok=True)

# %%
fname = folder+'grocery_sales'
joblib.dump(export, fname)
# Out:
# ['Models/grocery_sales']

# %%
loaded = joblib.load(fname)
loaded.keys()
# Out:
# dict_keys(['X_train', 'y_train', 'X_test', 'y_test', 'preprocessor', 'LinearRegression', 'RandomForestRegressor'])
